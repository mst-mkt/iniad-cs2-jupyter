# %%
import matplotlib.pyplot as plt
import math

# %%
xs: list[float] = []
ys: list[float] = []

for i in range(0, 201):
    x = (i / 10) -10
    xs.append(x)
    ys.append(math.sin(x))

plt.plot(xs, ys)
plt.title("y = sin(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
