# %%
import matplotlib.pyplot as plt
import math

# %%
xs: list[float] = []
ys: list[float] = []

for i in range (10):
    x = (i+1)*.1
    xs.append(x )
    ys.append(-math.log2(x))

plt.plot(xs, ys)
plt.title("y = -log2(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
